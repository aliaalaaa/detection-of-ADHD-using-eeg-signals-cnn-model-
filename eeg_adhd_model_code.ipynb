# %%
pip install mne
# Out:
# Collecting mne
#   Downloading mne-1.7.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.4)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from mne) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (24.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.1)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from mne) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.2.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.2.2)
# Installing collected packages: mne
# Successfully installed mne-1.7.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install glob2
# Out:
# Requirement already satisfied: glob2 in /usr/local/lib/python3.10/dist-packages (0.7)

# %%
import h5py
import os
import glob
import mne
import numpy as np
import scipy.io as sio
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import glob2 as glob

# %%
# Specify the channel types
ch_types = ['eeg'] * 19
ch_names = ['EEG1', 'EEG2', 'EEG3', 'EEG4','EEG5','EEG6','EEG7','EEG8','EEG9','EEG10','EEG11','EEG12','EEG13','EEG14','EEG15','EEG16','EEG17','EEG18','EEG19']

# Specify the output directory for .fif files
output_directory_path = '/content/drive/MyDrive/eeg_signals/ADHD_fif'

# Specify the directory containing your .mat EEG files
directory_path1 = '/content/drive/MyDrive/eeg_signals/ADHD_part1'
directory_path2 = '/content/drive/MyDrive/eeg_signals/ADHD_part2'

# Get a list of all .mat files in the directory
mat_files1 = glob.glob(os.path.join(directory_path1, '*.mat'))
mat_files2 = glob.glob(os.path.join(directory_path2, '*.mat'))
mat_files=mat_files1 + mat_files2

# Loop through each file
for mat_file in mat_files:
    mat_contents = sio.loadmat(mat_file)
    electrode_data = np.array(mat_contents[os.path.splitext(os.path.basename(mat_file))[0]])
    data = [i for i in electrode_data.T]  # Transpose the data


    # Create info and RawArray
    raw_info = mne.create_info(ch_names=ch_names, sfreq=128, ch_types=ch_types)
    raw = mne.io.RawArray(data, info=raw_info)

    # Save the RawArray to a .fif file in the output directory
    output_filename = os.path.splitext(os.path.basename(mat_file))[0] + '.fif'
    output_filepath = os.path.join(output_directory_path, output_filename)
    raw.save(output_filepath, overwrite=True)
    print(f"Saved {output_filepath}")



print("Processing complete!")
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=17561
#     Range : 0 ... 17560 =      0.000 ...   137.188 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v6p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v6p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v6p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v6p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=20097
#     Range : 0 ... 20096 =      0.000 ...   157.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v40p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v40p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v40p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v40p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=33570
#     Range : 0 ... 33569 =      0.000 ...   262.258 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v3p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v3p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v3p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v3p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18177
#     Range : 0 ... 18176 =      0.000 ...   142.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v39p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v39p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v39p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v39p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=24695
#     Range : 0 ... 24694 =      0.000 ...   192.922 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v38p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v38p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v38p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v38p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=9286
#     Range : 0 ... 9285 =      0.000 ...    72.539 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v37p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v37p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v37p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v37p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17401
#     Range : 0 ... 17400 =      0.000 ...   135.938 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v36p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v36p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v36p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v36p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15305
#     Range : 0 ... 15304 =      0.000 ...   119.562 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v35p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v35p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v35p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v35p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19555
#     Range : 0 ... 19554 =      0.000 ...   152.766 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v34p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v34p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v34p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v34p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=29217
#     Range : 0 ... 29216 =      0.000 ...   228.250 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v33p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v33p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v33p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v33p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18049
#     Range : 0 ... 18048 =      0.000 ...   141.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v32p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v32p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v32p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v32p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=11679
#     Range : 0 ... 11678 =      0.000 ...    91.234 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v31p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v31p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v31p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v31p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=21663
#     Range : 0 ... 21662 =      0.000 ...   169.234 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v30p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v30p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v30p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v30p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=24193
#     Range : 0 ... 24192 =      0.000 ...   189.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v29p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v29p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v29p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v29p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=27612
#     Range : 0 ... 27611 =      0.000 ...   215.711 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v28p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v28p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v28p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v28p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=28880
#     Range : 0 ... 28879 =      0.000 ...   225.617 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v27p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v27p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v27p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v27p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=9894
#     Range : 0 ... 9893 =      0.000 ...    77.289 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v25p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v25p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v25p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v25p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16385
#     Range : 0 ... 16384 =      0.000 ...   128.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v24p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v24p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v24p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v24p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12100
#     Range : 0 ... 12099 =      0.000 ...    94.523 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v22p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v22p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v22p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v22p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16574
#     Range : 0 ... 16573 =      0.000 ...   129.477 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v21p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v21p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v21p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v21p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=35328
#     Range : 0 ... 35327 =      0.000 ...   275.992 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v20p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v20p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v20p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v20p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12258
#     Range : 0 ... 12257 =      0.000 ...    95.758 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v1p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v1p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v1p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v1p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=23063
#     Range : 0 ... 23062 =      0.000 ...   180.172 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v19p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v19p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v19p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v19p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=25003
#     Range : 0 ... 25002 =      0.000 ...   195.328 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v18p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v18p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v18p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v18p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=24241
#     Range : 0 ... 24240 =      0.000 ...   189.375 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v173.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v173.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v173.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v173.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=43252
#     Range : 0 ... 43251 =      0.000 ...   337.898 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v15p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v15p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v15p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v15p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17562
#     Range : 0 ... 17561 =      0.000 ...   137.195 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v14p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v14p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v14p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v14p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17604
#     Range : 0 ... 17603 =      0.000 ...   137.523 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v12p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v12p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v12p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v12p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14304
#     Range : 0 ... 14303 =      0.000 ...   111.742 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v10p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v10p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v10p.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v10p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15776
#     Range : 0 ... 15775 =      0.000 ...   123.242 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v8p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v8p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v8p.fif
# Creating RawArray with float64 data, n_channels=19, n_times=27157
#     Range : 0 ... 27156 =      0.000 ...   212.156 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v219.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v219.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v219.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v8p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v219.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=21372
#     Range : 0 ... 21371 =      0.000 ...   166.961 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v215.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v215.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v215.fif
# Creating RawArray with float64 data, n_channels=19, n_times=12353
#     Range : 0 ... 12352 =      0.000 ...    96.500 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v213.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v213.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v213.fif
# Creating RawArray with float64 data, n_channels=19, n_times=30273
#     Range : 0 ... 30272 =      0.000 ...   236.500 secs
# Ready.
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v215.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v213.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v209.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v209.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v209.fif
# Creating RawArray with float64 data, n_channels=19, n_times=20173
#     Range : 0 ... 20172 =      0.000 ...   157.594 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v206.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v206.fif
# [done]
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v209.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v206.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v206.fif
# Creating RawArray with float64 data, n_channels=19, n_times=20456
#     Range : 0 ... 20455 =      0.000 ...   159.805 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v204.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v204.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v204.fif
# Creating RawArray with float64 data, n_channels=19, n_times=12739
#     Range : 0 ... 12738 =      0.000 ...    99.516 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v200.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v200.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v200.fif
# Creating RawArray with float64 data, n_channels=19, n_times=19621
#     Range : 0 ... 19620 =      0.000 ...   153.281 secs
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v204.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v200.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v198.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v198.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v198.fif
# Creating RawArray with float64 data, n_channels=19, n_times=13395
#     Range : 0 ... 13394 =      0.000 ...   104.641 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v196.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v196.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v196.fif
# Creating RawArray with float64 data, n_channels=19, n_times=15465
#     Range : 0 ... 15464 =      0.000 ...   120.812 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v190.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v198.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v196.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v190.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v190.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v190.fif
# Creating RawArray with float64 data, n_channels=19, n_times=18591
#     Range : 0 ... 18590 =      0.000 ...   145.234 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v183.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v183.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v183.fif
# Creating RawArray with float64 data, n_channels=19, n_times=10668
#     Range : 0 ... 10667 =      0.000 ...    83.336 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v181.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v181.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v181.fif
# Creating RawArray with float64 data, n_channels=19, n_times=12673
#     Range : 0 ... 12672 =      0.000 ...    99.000 secs
# Ready.
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v183.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v181.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v179.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v179.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v179.fif
# Creating RawArray with float64 data, n_channels=19, n_times=16697
#     Range : 0 ... 16696 =      0.000 ...   130.438 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v177.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v177.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v177.fif
# Creating RawArray with float64 data, n_channels=19, n_times=11465
#     Range : 0 ... 11464 =      0.000 ...    89.562 secs
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v179.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v177.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v286.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v286.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v286.fif
# Creating RawArray with float64 data, n_channels=19, n_times=15383
#     Range : 0 ... 15382 =      0.000 ...   120.172 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v284.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v284.fif
# [done]
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v286.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v284.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v284.fif
# Creating RawArray with float64 data, n_channels=19, n_times=20134
#     Range : 0 ... 20133 =      0.000 ...   157.289 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v279.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v279.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v279.fif
# Creating RawArray with float64 data, n_channels=19, n_times=17323
#     Range : 0 ... 17322 =      0.000 ...   135.328 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v274.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v274.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v274.fif
# Creating RawArray with float64 data, n_channels=19, n_times=23681
#     Range : 0 ... 23680 =      0.000 ...   185.000 secs
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v279.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v274.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v270.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v270.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v270.fif
# Creating RawArray with float64 data, n_channels=19, n_times=18389
#     Range : 0 ... 18388 =      0.000 ...   143.656 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v265.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v265.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v265.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v270.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v265.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18657
#     Range : 0 ... 18656 =      0.000 ...   145.750 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v263.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v263.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v263.fif
# Creating RawArray with float64 data, n_channels=19, n_times=10477
#     Range : 0 ... 10476 =      0.000 ...    81.844 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v254.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v254.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v254.fif
# Creating RawArray with float64 data, n_channels=19, n_times=13853
#     Range : 0 ... 13852 =      0.000 ...   108.219 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v250.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v263.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v254.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v250.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v250.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v250.fif
# Creating RawArray with float64 data, n_channels=19, n_times=21307
#     Range : 0 ... 21306 =      0.000 ...   166.453 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v246.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v246.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v246.fif
# Creating RawArray with float64 data, n_channels=19, n_times=39030
#     Range : 0 ... 39029 =      0.000 ...   304.914 secs
# Ready.
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v246.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v244.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v244.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v244.fif
# Creating RawArray with float64 data, n_channels=19, n_times=9852
#     Range : 0 ... 9851 =      0.000 ...    76.961 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v238.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v238.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v238.fif
# Creating RawArray with float64 data, n_channels=19, n_times=13502
#     Range : 0 ... 13501 =      0.000 ...   105.477 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v236.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v244.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v238.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v236.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v236.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v236.fif
# Creating RawArray with float64 data, n_channels=19, n_times=34191
#     Range : 0 ... 34190 =      0.000 ...   267.109 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v234.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v234.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v234.fif
# Creating RawArray with float64 data, n_channels=19, n_times=19713
#     Range : 0 ... 19712 =      0.000 ...   154.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v231.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v234.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v231.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v231.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v231.fif
# Creating RawArray with float64 data, n_channels=19, n_times=28080
#     Range : 0 ... 28079 =      0.000 ...   219.367 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v227.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v227.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v227.fif
# Creating RawArray with float64 data, n_channels=19, n_times=20115
#     Range : 0 ... 20114 =      0.000 ...   157.141 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v288.fif
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v227.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# <ipython-input-9-4d0b226b5e5d>:31: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v288.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v288.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/ADHD_fif/v288.fif
# Processing complete!

# %%
raw = mne.io.read_raw_fif(r'/content/drive/MyDrive/eeg_signals/ADHD_fif/v10p.fif' ,preload=True)
# Out:
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v10p.fif...
# <ipython-input-11-cf69c5a40d25>:1: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v10p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(r'/content/drive/MyDrive/eeg_signals/ADHD_fif/v10p.fif' ,preload=True)
# Isotrak not found
#     Range : 0 ... 14303 =      0.000 ...   111.742 secs
# Ready.
# Reading 0 ... 14303  =      0.000 ...   111.742 secs...

# %%
raw.compute_psd(fmax=64).plot(picks="data", exclude="bads")
# Out:
# Effective window size : 16.000 (s)
# Plotting power spectral density (dB=True).
# <ipython-input-12-b540e28d23d3>:1: FutureWarning: The value of `amplitude='auto'` will be removed in MNE 1.8.0, and the new default will be `amplitude=False`.
#   raw.compute_psd(fmax=64).plot(picks="data", exclude="bads")
# <ipython-input-12-b540e28d23d3>:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.compute_psd(fmax=64).plot(picks="data", exclude="bads")
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
# Specify the output directory for .fif files
output_directory_path = '/content/drive/MyDrive/eeg_signals/Control_fif'

# Specify the directory containing your .mat EEG files
directory_path1 = '/content/drive/MyDrive/eeg_signals/Control_part1'
directory_path2 = '/content/drive/MyDrive/eeg_signals/Control_part2'

# Get a list of all .mat files in the directory
mat_files1 = glob.glob(os.path.join(directory_path1, '*.mat'))
mat_files2 = glob.glob(os.path.join(directory_path2, '*.mat'))
mat_files=mat_files1 + mat_files2

# Loop through each file
for mat_file in mat_files:
    mat_contents = sio.loadmat(mat_file)
    electrode_data = np.array(mat_contents[os.path.splitext(os.path.basename(mat_file))[0]])
    data = [i for i in electrode_data.T]  # Transpose the data


    # Create info and RawArray
    raw_info = mne.create_info(ch_names=ch_names, sfreq=128, ch_types=ch_types)
    raw = mne.io.RawArray(data, info=raw_info)

    # Save the RawArray to a .fif file in the output directory
    output_filename = os.path.splitext(os.path.basename(mat_file))[0] + '.fif'
    output_filepath = os.path.join(output_directory_path, output_filename)
    raw.save(output_filepath, overwrite=True)
    print(f"Saved {output_filepath}")



print("Processing complete!")
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=16549
#     Range : 0 ... 16548 =      0.000 ...   129.281 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v110.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v110.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v110.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v110.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16044
#     Range : 0 ... 16043 =      0.000 ...   125.336 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v109.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v109.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v109.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v109.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19026
#     Range : 0 ... 19025 =      0.000 ...   148.633 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v108.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v108.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v108.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v108.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19794
#     Range : 0 ... 19793 =      0.000 ...   154.633 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v107.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v107.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v107.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v107.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19234
#     Range : 0 ... 19233 =      0.000 ...   150.258 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13883
#     Range : 0 ... 13882 =      0.000 ...   108.453 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=7983
#     Range : 0 ... 7982 =      0.000 ...    62.359 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16239
#     Range : 0 ... 16238 =      0.000 ...   126.859 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16769
#     Range : 0 ... 16768 =      0.000 ...   131.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=10452
#     Range : 0 ... 10451 =      0.000 ...    81.648 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=10864
#     Range : 0 ... 10863 =      0.000 ...    84.867 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=9823
#     Range : 0 ... 9822 =      0.000 ...    76.734 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=10871
#     Range : 0 ... 10870 =      0.000 ...    84.922 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=11393
#     Range : 0 ... 11392 =      0.000 ...    89.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12750
#     Range : 0 ... 12749 =      0.000 ...    99.602 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16704
#     Range : 0 ... 16703 =      0.000 ...   130.492 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12500
#     Range : 0 ... 12499 =      0.000 ...    97.648 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19301
#     Range : 0 ... 19300 =      0.000 ...   150.781 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v116.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v116.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v116.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v116.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15651
#     Range : 0 ... 15650 =      0.000 ...   122.266 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v115.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v115.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v115.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v115.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13304
#     Range : 0 ... 13303 =      0.000 ...   103.930 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v114.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v114.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v114.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v114.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15574
#     Range : 0 ... 15573 =      0.000 ...   121.664 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v113.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v113.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v113.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v113.fif
# Creating RawArray with float64 data, n_channels=19, n_times=15943
#     Range : 0 ... 15942 =      0.000 ...   124.547 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v112.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v112.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v112.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v112.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15310
#     Range : 0 ... 15309 =      0.000 ...   119.602 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v111.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v111.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v111.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v111.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16513
#     Range : 0 ... 16512 =      0.000 ...   129.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v59p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v59p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v59p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v59p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12929
#     Range : 0 ... 12928 =      0.000 ...   101.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v60p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v60p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v60p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v60p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13918
#     Range : 0 ... 13917 =      0.000 ...   108.727 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v58p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v58p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v58p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v58p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14692
#     Range : 0 ... 14691 =      0.000 ...   114.773 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v57p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v57p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v57p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v57p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14139
#     Range : 0 ... 14138 =      0.000 ...   110.453 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v56p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v56p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v56p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v56p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14282
#     Range : 0 ... 14281 =      0.000 ...   111.570 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v55p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v55p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v55p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v55p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19122
#     Range : 0 ... 19121 =      0.000 ...   149.383 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v53p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v53p.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v53p.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v53p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12488
#     Range : 0 ... 12487 =      0.000 ...    97.555 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v138.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v138.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v138.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v138.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13359
#     Range : 0 ... 13358 =      0.000 ...   104.359 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v134.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v134.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v134.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v134.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15073
#     Range : 0 ... 15072 =      0.000 ...   117.750 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v133.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v133.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v133.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v133.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16686
#     Range : 0 ... 16685 =      0.000 ...   130.352 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v131.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v131.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v131.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v131.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=11208
#     Range : 0 ... 11207 =      0.000 ...    87.555 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v129.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v129.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v129.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v129.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14721
#     Range : 0 ... 14720 =      0.000 ...   115.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v127.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v127.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v127.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v127.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15378
#     Range : 0 ... 15377 =      0.000 ...   120.133 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v125.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v125.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v125.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v125.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14550
#     Range : 0 ... 14549 =      0.000 ...   113.664 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v123.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v123.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v123.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v123.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=16377
#     Range : 0 ... 16376 =      0.000 ...   127.938 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v121.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v121.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v121.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v121.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12033
#     Range : 0 ... 12032 =      0.000 ...    94.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v120.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v120.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v120.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v120.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=12007
#     Range : 0 ... 12006 =      0.000 ...    93.797 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v118.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v118.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v118.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v118.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=25659
#     Range : 0 ... 25658 =      0.000 ...   200.453 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v117.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v117.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v117.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v117.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=22807
#     Range : 0 ... 22806 =      0.000 ...   178.172 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v307.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v307.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v307.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v307.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=18301
#     Range : 0 ... 18300 =      0.000 ...   142.969 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v306.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v306.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v306.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v306.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=22273
#     Range : 0 ... 22272 =      0.000 ...   174.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v305.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v305.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v305.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v305.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13400
#     Range : 0 ... 13399 =      0.000 ...   104.680 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v304.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v304.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v304.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v304.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=19222
#     Range : 0 ... 19221 =      0.000 ...   150.164 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v303.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v303.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v303.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v303.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17841
#     Range : 0 ... 17840 =      0.000 ...   139.375 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v302.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v302.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v302.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v302.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=25985
#     Range : 0 ... 25984 =      0.000 ...   203.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v300.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v300.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v300.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v300.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=22260
#     Range : 0 ... 22259 =      0.000 ...   173.898 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v299.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v299.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v299.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v299.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17782
#     Range : 0 ... 17781 =      0.000 ...   138.914 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v298.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v298.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v298.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v298.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=13697
#     Range : 0 ... 13696 =      0.000 ...   107.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v297.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v297.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v297.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v297.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=20914
#     Range : 0 ... 20913 =      0.000 ...   163.383 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v151.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v151.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v151.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v151.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17098
#     Range : 0 ... 17097 =      0.000 ...   133.570 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v149.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v149.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v149.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v149.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=14209
#     Range : 0 ... 14208 =      0.000 ...   111.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v147.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v147.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v147.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v147.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=15607
#     Range : 0 ... 15606 =      0.000 ...   121.922 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v143.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v143.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v143.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v143.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17187
#     Range : 0 ... 17186 =      0.000 ...   134.266 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v140.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v140.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v140.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v140.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17793
#     Range : 0 ... 17792 =      0.000 ...   139.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v310.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v310.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v310.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v310.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=24818
#     Range : 0 ... 24817 =      0.000 ...   193.883 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v309.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v309.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v309.fif
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v309.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)
# Creating RawArray with float64 data, n_channels=19, n_times=17025
#     Range : 0 ... 17024 =      0.000 ...   133.000 secs
# Ready.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v308.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v308.fif
# [done]
# Saved /content/drive/MyDrive/eeg_signals/Control_fif/v308.fif
# Processing complete!
# <ipython-input-13-7377fd4413cc>:27: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v308.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_filepath, overwrite=True)

# %%
import os

folder_path = '/content/drive/MyDrive/eeg_signals/ADHD_fif'
for filename in os.listdir(folder_path):
    if filename.endswith('.fif'):
        # read .fif file
        file_path = os.path.join(folder_path, filename)
        raw = mne.io.read_raw_fif(file_path ,preload=True)

        l_freq = 0.5  # Cutoff frequency in Hz (e.g., remove slow drifts below 1 Hz)
        # Apply Cutoff frequency filter
        filtered_data=raw.filter(l_freq=l_freq, h_freq=None, fir_design='firwin', phase='zero')  # None for no high-frequency cutoff

        fnotch = 50  # Notch filter frequency (e.g., remove 50 Hz power line noise)
        # Apply notch filter
        filteredd_data = filtered_data.notch_filter(freqs=fnotch, picks=None, fir_design='firwin', phase='zero')

        #applying zero padding on the file
        n_zeros = 2
        zero_padding = np.zeros(n_zeros)
        data = filteredd_data.get_data()
        # Create a new array to hold the padded data
        padded_data = np.zeros((data.shape[0], data.shape[1] + 2 * n_zeros))

        # Iterate over each channel and apply zero-padding
        for ch_idx in range(data.shape[0]):
            channel_data = data[ch_idx]
            channel_padded = np.concatenate((zero_padding, channel_data, zero_padding))
            padded_data[ch_idx] = channel_padded

        # Create a new info object
        info = raw.info

        # Create a new RawArray object with the modified data
        raw_padded = mne.io.RawArray(padded_data, info)

        #applying moving avg filter
        # Iterate over each channel
        for i in range(len(raw_padded.ch_names)):
            # Get the data for the current channel
            data = raw_padded.get_data()[i]

            # Calculate the rolling mean
            moving_avg = pd.Series(data).rolling(window=5, min_periods=1).mean()

            # Replace NaNs in the rolling mean with zeros
            moving_avg = moving_avg.fillna(0)

            # Update the data in the Raw object with the rolling mean
            raw_padded._data[i] = moving_avg.values


        # Apply spatial filtering using Common Average Reference (CAR)
        raw_car = raw_padded.set_eeg_reference('average', projection=True)

        # Apply the projection to actually re-reference the data
        raw_car.apply_proj()


        # Save the modified Raw object back to the same file
        raw_car.save(file_path, overwrite=True)


print("Processing complete!")
# Out:
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v6p.fif...
# Isotrak not found
#     Range : 0 ... 17560 =      0.000 ...   137.188 secs
# Ready.
# Reading 0 ... 17560  =      0.000 ...   137.188 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v6p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=17565
#     Range : 0 ... 17564 =      0.000 ...   137.219 secs
# Ready.
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v6p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v6p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v40p.fif...
# Isotrak not found
#     Range : 0 ... 20096 =      0.000 ...   157.000 secs
# Ready.
# Reading 0 ... 20096  =      0.000 ...   157.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v6p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v40p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=20101
#     Range : 0 ... 20100 =      0.000 ...   157.031 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v40p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v40p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v3p.fif...
# Isotrak not found
#     Range : 0 ... 33569 =      0.000 ...   262.258 secs
# Ready.
# Reading 0 ... 33569  =      0.000 ...   262.258 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v40p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v3p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=33574
#     Range : 0 ... 33573 =      0.000 ...   262.289 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v3p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v3p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v39p.fif...
# Isotrak not found
#     Range : 0 ... 18176 =      0.000 ...   142.000 secs
# Ready.
# Reading 0 ... 18176  =      0.000 ...   142.000 secs...
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v3p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v39p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=18181
#     Range : 0 ... 18180 =      0.000 ...   142.031 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v39p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v39p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v38p.fif...
# Isotrak not found
#     Range : 0 ... 24694 =      0.000 ...   192.922 secs
# Ready.
# Reading 0 ... 24694  =      0.000 ...   192.922 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v39p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v38p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=24699
#     Range : 0 ... 24698 =      0.000 ...   192.953 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v38p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v38p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v37p.fif...
# Isotrak not found
#     Range : 0 ... 9285 =      0.000 ...    72.539 secs
# Ready.
# Reading 0 ... 9285  =      0.000 ...    72.539 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v38p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v37p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=9290
#     Range : 0 ... 9289 =      0.000 ...    72.570 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v37p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v37p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v37p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v36p.fif...
# Isotrak not found
#     Range : 0 ... 17400 =      0.000 ...   135.938 secs
# Ready.
# Reading 0 ... 17400  =      0.000 ...   135.938 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v36p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=17405
#     Range : 0 ... 17404 =      0.000 ...   135.969 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v36p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v36p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v36p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v35p.fif...
# Isotrak not found
#     Range : 0 ... 15304 =      0.000 ...   119.562 secs
# Ready.
# Reading 0 ... 15304  =      0.000 ...   119.562 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v35p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=15309
#     Range : 0 ... 15308 =      0.000 ...   119.594 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v35p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v35p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v34p.fif...
# Isotrak not found
#     Range : 0 ... 19554 =      0.000 ...   152.766 secs
# Ready.
# Reading 0 ... 19554  =      0.000 ...   152.766 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v35p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v34p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=19559
#     Range : 0 ... 19558 =      0.000 ...   152.797 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v34p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v34p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v33p.fif...
# Isotrak not found
#     Range : 0 ... 29216 =      0.000 ...   228.250 secs
# Ready.
# Reading 0 ... 29216  =      0.000 ...   228.250 secs...
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v34p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v33p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=29221
#     Range : 0 ... 29220 =      0.000 ...   228.281 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v33p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v33p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v32p.fif...
# Isotrak not found
#     Range : 0 ... 18048 =      0.000 ...   141.000 secs
# Ready.
# Reading 0 ... 18048  =      0.000 ...   141.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v33p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v32p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=18053
#     Range : 0 ... 18052 =      0.000 ...   141.031 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v32p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v32p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v32p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v31p.fif...
# Isotrak not found
#     Range : 0 ... 11678 =      0.000 ...    91.234 secs
# Ready.
# Reading 0 ... 11678  =      0.000 ...    91.234 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=11683
#     Range : 0 ... 11682 =      0.000 ...    91.266 secs
# Ready.
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v31p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v31p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v31p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v30p.fif...
# Isotrak not found
#     Range : 0 ... 21662 =      0.000 ...   169.234 secs
# Ready.
# Reading 0 ... 21662  =      0.000 ...   169.234 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v31p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v30p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=21667
#     Range : 0 ... 21666 =      0.000 ...   169.266 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v30p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v30p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v30p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v29p.fif...
# Isotrak not found
#     Range : 0 ... 24192 =      0.000 ...   189.000 secs
# Ready.
# Reading 0 ... 24192  =      0.000 ...   189.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=24197
#     Range : 0 ... 24196 =      0.000 ...   189.031 secs
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v29p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v29p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v29p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v28p.fif...
# Isotrak not found
#     Range : 0 ... 27611 =      0.000 ...   215.711 secs
# Ready.
# Reading 0 ... 27611  =      0.000 ...   215.711 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v29p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v28p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=27616
#     Range : 0 ... 27615 =      0.000 ...   215.742 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v28p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v28p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v28p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v27p.fif...
# Isotrak not found
#     Range : 0 ... 28879 =      0.000 ...   225.617 secs
# Ready.
# Reading 0 ... 28879  =      0.000 ...   225.617 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v27p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=28884
#     Range : 0 ... 28883 =      0.000 ...   225.648 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v27p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v27p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v27p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v25p.fif...
# Isotrak not found
#     Range : 0 ... 9893 =      0.000 ...    77.289 secs
# Ready.
# Reading 0 ... 9893  =      0.000 ...    77.289 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v25p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=9898
#     Range : 0 ... 9897 =      0.000 ...    77.320 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v25p.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v25p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v24p.fif...
# Isotrak not found
#     Range : 0 ... 16384 =      0.000 ...   128.000 secs
# Ready.
# Reading 0 ... 16384  =      0.000 ...   128.000 secs...
# Filtering raw data in 1 contiguous segment
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v25p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v24p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ...
# Ready.
# Reading 0 ... 9851  =      0.000 ...    76.961 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=9856
#     Range : 0 ... 9855 =      0.000 ...    76.992 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v238.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v238.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v238.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v236.fif...
# Isotrak not found
#     Range : 0 ... 13501 =      0.000 ...   105.477 secs
# Ready.
# Reading 0 ... 13501  =      0.000 ...   105.477 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v236.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=13506
#     Range : 0 ... 13505 =      0.000 ...   105.508 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v236.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v236.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v234.fif...
# Isotrak not found
#     Range : 0 ... 34190 =      0.000 ...   267.109 secs
# Ready.
# Reading 0 ... 34190  =      0.000 ...   267.109 secs...
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v236.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v234.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=34195
#     Range : 0 ... 34194 =      0.000 ...   267.141 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v234.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v234.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v231.fif...
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v234.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v231.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Isotrak not found
#     Range : 0 ... 19712 =      0.000 ...   154.000 secs
# Ready.
# Reading 0 ... 19712  =      0.000 ...   154.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=19717
#     Range : 0 ... 19716 =      0.000 ...   154.031 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v231.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v231.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v227.fif...
# Isotrak not found
#     Range : 0 ... 28079 =      0.000 ...   219.367 secs
# Ready.
# Reading 0 ... 28079  =      0.000 ...   219.367 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v231.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v227.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=28084
#     Range : 0 ... 28083 =      0.000 ...   219.398 secs
# Ready.
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v227.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v227.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v288.fif...
# Isotrak not found
#     Range : 0 ... 20114 =      0.000 ...   157.141 secs
# Ready.
# Reading 0 ... 20114  =      0.000 ...   157.141 secs...
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v227.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-14-02c03a9f30b1>:8: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v288.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=20119
#     Range : 0 ... 20118 =      0.000 ...   157.172 secs
# Ready.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/ADHD_fif/v288.fif
# Closing /content/drive/MyDrive/eeg_signals/ADHD_fif/v288.fif
# [done]
# Processing complete!
# <ipython-input-14-02c03a9f30b1>:61: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v288.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)

# %%
folder_path = '/content/drive/MyDrive/eeg_signals/Control_fif'

for filename in os.listdir(folder_path):
    if filename.endswith('.fif'):
        # read .fif file
        file_path = os.path.join(folder_path, filename)
        raw = mne.io.read_raw_fif(file_path ,preload=True)

        l_freq = 0.5  # Cutoff frequency in Hz (e.g., remove slow drifts below 1 Hz)
        # Apply Cutoff frequency filter
        filtered_data=raw.filter(l_freq=l_freq, h_freq=None, fir_design='firwin', phase='zero')  # None for no high-frequency cutoff

        fnotch = 50  # Notch filter frequency (e.g., remove 50 Hz power line noise)
        # Apply notch filter
        filteredd_data = filtered_data.notch_filter(freqs=fnotch, picks=None, fir_design='firwin', phase='zero')

        #applying zero padding on the file
        n_zeros = 2
        zero_padding = np.zeros(n_zeros)
        data = filteredd_data.get_data()
        # Create a new array to hold the padded data
        padded_data = np.zeros((data.shape[0], data.shape[1] + 2 * n_zeros))

        # Iterate over each channel and apply zero-padding
        for ch_idx in range(data.shape[0]):
            channel_data = data[ch_idx]
            channel_padded = np.concatenate((zero_padding, channel_data, zero_padding))
            padded_data[ch_idx] = channel_padded

        # Create a new info object
        info = raw.info

        # Create a new RawArray object with the modified data
        raw_padded = mne.io.RawArray(padded_data, info)

        #applying moving avg filter
        # Iterate over each channel
        for i in range(len(raw_padded.ch_names)):
            # Get the data for the current channel
            data = raw_padded.get_data()[i]

            # Calculate the rolling mean
            moving_avg = pd.Series(data).rolling(window=5, min_periods=1).mean()

            # Replace NaNs in the rolling mean with zeros
            moving_avg = moving_avg.fillna(0)

            # Update the data in the Raw object with the rolling mean
            raw_padded._data[i] = moving_avg.values


        # Apply spatial filtering using Common Average Reference (CAR)
        raw_car = raw_padded.set_eeg_reference('average', projection=True)

        # Apply the projection to actually re-reference the data
        raw_car.apply_proj()


        # Save the modified Raw object back to the same file
        raw_car.save(file_path, overwrite=True)
print("Processing complete!")
# Out:
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v110.fif...
# Isotrak not found
#     Range : 0 ... 16548 =      0.000 ...   129.281 secs
# Ready.
# Reading 0 ... 16548  =      0.000 ...   129.281 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=16553
#     Range : 0 ... 16552 =      0.000 ...   129.312 secs
# Ready.
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v110.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v110.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v110.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v109.fif...
# Isotrak not found
#     Range : 0 ... 16043 =      0.000 ...   125.336 secs
# Ready.
# Reading 0 ... 16043  =      0.000 ...   125.336 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v110.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v109.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=16048
#     Range : 0 ... 16047 =      0.000 ...   125.367 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v109.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v109.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v108.fif...
# Isotrak not found
#     Range : 0 ... 19025 =      0.000 ...   148.633 secs
# Ready.
# Reading 0 ... 19025  =      0.000 ...   148.633 secs...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v109.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v108.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=19030
#     Range : 0 ... 19029 =      0.000 ...   148.664 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v108.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v108.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v108.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v107.fif...
# Isotrak not found
#     Range : 0 ... 19793 =      0.000 ...   154.633 secs
# Ready.
# Reading 0 ... 19793  =      0.000 ...   154.633 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=19798
#     Range : 0 ... 19797 =      0.000 ...   154.664 secs
# Ready.
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v107.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v107.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v107.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif...
# Isotrak not found
#     Range : 0 ... 19233 =      0.000 ...   150.258 secs
# Ready.
# Reading 0 ... 19233  =      0.000 ...   150.258 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v107.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=19238
#     Range : 0 ... 19237 =      0.000 ...   150.289 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif...
# Isotrak not found
#     Range : 0 ... 13882 =      0.000 ...   108.453 secs
# Ready.
# Reading 0 ... 13882  =      0.000 ...   108.453 secs...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=13887
#     Range : 0 ... 13886 =      0.000 ...   108.484 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Isotrak not found
#     Range : 0 ... 7982 =      0.000 ...    62.359 secs
# Ready.
# Reading 0 ... 7982  =      0.000 ...    62.359 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=7987
#     Range : 0 ... 7986 =      0.000 ...    62.391 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif...
# Isotrak not found
#     Range : 0 ... 16238 =      0.000 ...   126.859 secs
# Ready.
# Reading 0 ... 16238  =      0.000 ...   126.859 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=16243
#     Range : 0 ... 16242 =      0.000 ...   126.891 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Isotrak not found
#     Range : 0 ... 16768 =      0.000 ...   131.000 secs
# Ready.
# Reading 0 ... 16768  =      0.000 ...   131.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=16773
#     Range : 0 ... 16772 =      0.000 ...   131.031 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif...
# Isotrak not found
#     Range : 0 ... 10451 =      0.000 ...    81.648 secs
# Ready.
# Reading 0 ... 10451  =      0.000 ...    81.648 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=10456
#     Range : 0 ... 10455 =      0.000 ...    81.680 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif...
# Isotrak not found
#     Range : 0 ... 10863 =      0.000 ...    84.867 secs
# Ready.
# Reading 0 ... 10863  =      0.000 ...    84.867 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=10868
#     Range : 0 ... 10867 =      0.000 ...    84.898 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif...
# Isotrak not found
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
#     Range : 0 ... 9822 =      0.000 ...    76.734 secs
# Ready.
# Reading 0 ... 9822  =      0.000 ...    76.734 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=9827
#     Range : 0 ... 9826 =      0.000 ...    76.766 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif...
# Isotrak not found
#     Range : 0 ... 10870 =      0.000 ...    84.922 secs
# Ready.
# Reading 0 ... 10870  =      0.000 ...    84.922 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=10875
#     Range : 0 ... 10874 =      0.000 ...    84.953 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif
# [done]
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif...
# Isotrak not found
#     Range : 0 ... 11392 =      0.000 ...    89.000 secs
# Ready.
# Reading 0 ... 11392  =      0.000 ...    89.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=11397
#     Range : 0 ... 11396 =      0.000 ...    89.031 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif...
# Isotrak not found
#     Range : 0 ... 12749 =      0.000 ...    99.602 secs
# Ready.
# Reading 0 ... 12749  =      0.000 ...    99.602 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=12754
#     Range : 0 ... 12753 =      0.000 ...    99.633 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif...
# Isotrak not found
#     Range : 0 ... 16703 =      0.000 ...   130.492 secs
# Ready.
# Reading 0 ... 16703  =      0.000 ...   130.492 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=16708
#     Range : 0 ... 16707 =      0.000 ...   130.523 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif...
# Isotrak not found
#     Range : 0 ... 12499 =      0.000 ...    97.648 secs
# Ready.
# Reading 0 ... 12499  =      0.000 ...    97.648 secs...
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=12504
#     Range : 0 ... 12503 =      0.000 ...    97.680 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v116.fif...
# Isotrak not found
#     Range : 0 ... 19300 =      0.000 ...   150.781 secs
# Ready.
# Reading 0 ... 19300  =      0.000 ...   150.781 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ...
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v147.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=14213
#     Range : 0 ... 14212 =      0.000 ...   111.031 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v147.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v147.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v143.fif...
# Isotrak not found
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v147.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v143.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
#     Range : 0 ... 15606 =      0.000 ...   121.922 secs
# Ready.
# Reading 0 ... 15606  =      0.000 ...   121.922 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=15611
#     Range : 0 ... 15610 =      0.000 ...   121.953 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v143.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v143.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v143.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v140.fif...
# Isotrak not found
#     Range : 0 ... 17186 =      0.000 ...   134.266 secs
# Ready.
# Reading 0 ... 17186  =      0.000 ...   134.266 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v140.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=17191
#     Range : 0 ... 17190 =      0.000 ...   134.297 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v140.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v140.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v140.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v310.fif...
# Isotrak not found
#     Range : 0 ... 17792 =      0.000 ...   139.000 secs
# Ready.
# Reading 0 ... 17792  =      0.000 ...   139.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v310.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=17797
#     Range : 0 ... 17796 =      0.000 ...   139.031 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v310.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v310.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v310.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v309.fif...
# Isotrak not found
#     Range : 0 ... 24817 =      0.000 ...   193.883 secs
# Ready.
# Reading 0 ... 24817  =      0.000 ...   193.883 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v309.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Creating RawArray with float64 data, n_channels=19, n_times=24822
#     Range : 0 ... 24821 =      0.000 ...   193.914 secs
# Ready.
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v309.fif
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v309.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v309.fif
# [done]
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v308.fif...
# Isotrak not found
#     Range : 0 ... 17024 =      0.000 ...   133.000 secs
# Ready.
# Reading 0 ... 17024  =      0.000 ...   133.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 845 samples (6.602 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=17029
#     Range : 0 ... 17028 =      0.000 ...   133.031 secs
# Ready.
# <ipython-input-15-c69d832b625b>:7: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v308.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path ,preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing /content/drive/MyDrive/eeg_signals/Control_fif/v308.fif
# Closing /content/drive/MyDrive/eeg_signals/Control_fif/v308.fif
# [done]
# Processing complete!
# <ipython-input-15-c69d832b625b>:60: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v308.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_car.save(file_path, overwrite=True)

# %%
raw_car.compute_psd(fmax=64).plot(picks="data", exclude="bads")
# Out:
# Effective window size : 16.000 (s)
# Plotting power spectral density (dB=True).
# <ipython-input-16-d2668c560f4f>:1: FutureWarning: The value of `amplitude='auto'` will be removed in MNE 1.8.0, and the new default will be `amplitude=False`.
#   raw_car.compute_psd(fmax=64).plot(picks="data", exclude="bads")
# <ipython-input-16-d2668c560f4f>:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw_car.compute_psd(fmax=64).plot(picks="data", exclude="bads")
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
#creating a list with the paths of the adhd files
ADHD_files_path = glob.glob(os.path.join('/content/drive/MyDrive/eeg_signals/ADHD_fif', '*.fif'))
ADHD_files_path_50 = ADHD_files_path[:50]
print(len(ADHD_files_path_50))
# Out:
# 50

# %%
#creating a list with the paths of the control files
control_files_path=glob.glob(os.path.join(r'/content/drive/MyDrive/eeg_signals/Control_fif/','*.fif'))
print(len(control_files_path))
# Out:
# 60

# %%
#creating a function to read the data and create a fixed epochs of duration 10 sec and overlapping of 75%
def read_data(file_path):
    datax=mne.io.read_raw_fif(file_path,preload=True)
    epochs=mne.make_fixed_length_epochs(datax,duration=10,overlap=0.75)
    epochs=epochs.get_data() #turning the epochs to arrays
    return epochs

# %%
#reading the data of both ADHD and control and saving them in an array
NON_ADHD_epochs_array=[read_data(subject) for subject in control_files_path]
ADHD_epochs_array=[read_data(subject) for subject in ADHD_files_path_50]
# Out:
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v110.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16552 =      0.000 ...   129.312 secs
# Ready.
# Reading 0 ... 16552  =      0.000 ...   129.312 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v109.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16047 =      0.000 ...   125.367 secs
# Ready.
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v110.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v109.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Reading 0 ... 16047  =      0.000 ...   125.367 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v108.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19029 =      0.000 ...   148.664 secs
# Ready.
# Reading 0 ... 19029  =      0.000 ...   148.664 secs...
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 15 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v107.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v108.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v107.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19797 =      0.000 ...   154.664 secs
# Ready.
# Reading 0 ... 19797  =      0.000 ...   154.664 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19237 =      0.000 ...   150.289 secs
# Ready.
# Reading 0 ... 19237  =      0.000 ...   150.289 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13886 =      0.000 ...   108.484 secs
# Ready.
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v54p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v52p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Reading 0 ... 13886  =      0.000 ...   108.484 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 7986 =      0.000 ...    62.391 secs
# Ready.
# Reading 0 ... 7986  =      0.000 ...    62.391 secs...
# Not setting metadata
# 6 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 6 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16242 =      0.000 ...   126.891 secs
# Ready.
# Reading 0 ... 16242  =      0.000 ...   126.891 secs...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v51p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v50p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16772 =      0.000 ...   131.031 secs
# Ready.
# Reading 0 ... 16772  =      0.000 ...   131.031 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 10455 =      0.000 ...    81.680 secs
# Ready.
# Reading 0 ... 10455  =      0.000 ...    81.680 secs...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v49p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v48p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Not setting metadata
# 8 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 8 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 10867 =      0.000 ...    84.898 secs
# Ready.
# Reading 0 ... 10867  =      0.000 ...    84.898 secs...
# Not setting metadata
# 9 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 9 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 9826 =      0.000 ...    76.766 secs
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v47p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v46p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Ready.
# Reading 0 ... 9826  =      0.000 ...    76.766 secs...
# Not setting metadata
# 8 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 8 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 10874 =      0.000 ...    84.953 secs
# Ready.
# Reading 0 ... 10874  =      0.000 ...    84.953 secs...
# Not setting metadata
# 9 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 9 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v45p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v44p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 11396 =      0.000 ...    89.031 secs
# Ready.
# Reading 0 ... 11396  =      0.000 ...    89.031 secs...
# Not setting metadata
# 9 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 9 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12753 =      0.000 ...    99.633 secs
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v43p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Ready.
# Reading 0 ... 12753  =      0.000 ...    99.633 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16707 =      0.000 ...   130.523 secs
# Ready.
# Reading 0 ... 16707  =      0.000 ...   130.523 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v42p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v41p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12503 =      0.000 ...    97.680 secs
# Ready.
# Reading 0 ... 12503  =      0.000 ...    97.680 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v116.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19304 =      0.000 ...   150.812 secs
# Ready.
# Reading 0 ... 19304  =      0.000 ...   150.812 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v115.fif...
# Isotrak not found
#     Read a total of 1 projection items:
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v116.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v115.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15654 =      0.000 ...   122.297 secs
# Ready.
# Reading 0 ... 15654  =      0.000 ...   122.297 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v114.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13307 =      0.000 ...   103.961 secs
# Ready.
# Reading 0 ... 13307  =      0.000 ...   103.961 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v113.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15577 =      0.000 ...   121.695 secs
# Ready.
# Reading 0 ... 15577  =      0.000 ...   121.695 secs...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v114.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v113.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v112.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15946 =      0.000 ...   124.578 secs
# Ready.
# Reading 0 ... 15946  =      0.000 ...   124.578 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v111.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v112.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v111.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15313 =      0.000 ...   119.633 secs
# Ready.
# Reading 0 ... 15313  =      0.000 ...   119.633 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v59p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16516 =      0.000 ...   129.031 secs
# Ready.
# Reading 0 ... 16516  =      0.000 ...   129.031 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v60p.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v59p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12932 =      0.000 ...   101.031 secs
# Ready.
# Reading 0 ... 12932  =      0.000 ...   101.031 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v58p.fif...
# Isotrak not found
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v60p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v58p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13921 =      0.000 ...   108.758 secs
# Ready.
# Reading 0 ... 13921  =      0.000 ...   108.758 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v57p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 14695 =      0.000 ...   114.805 secs
# Ready.
# Reading 0 ... 14695  =      0.000 ...   114.805 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v56p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v57p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v56p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
#     Range : 0 ... 14142 =      0.000 ...   110.484 secs
# Ready.
# Reading 0 ... 14142  =      0.000 ...   110.484 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v55p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 14285 =      0.000 ...   111.602 secs
# Ready.
# Reading 0 ... 14285  =      0.000 ...   111.602 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v53p.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19125 =      0.000 ...   149.414 secs
# Ready.
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v55p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v53p.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Reading 0 ... 19125  =      0.000 ...   149.414 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v138.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12491 =      0.000 ...    97.586 secs
# Ready.
# Reading 0 ... 12491  =      0.000 ...    97.586 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v134.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13362 =      0.000 ...   104.391 secs
# Ready.
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v138.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v134.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Reading 0 ... 13362  =      0.000 ...   104.391 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v133.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15076 =      0.000 ...   117.781 secs
# Ready.
# Reading 0 ... 15076  =      0.000 ...   117.781 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v131.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16689 =      0.000 ...   130.383 secs
# Ready.
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v133.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v131.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Reading 0 ... 16689  =      0.000 ...   130.383 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v129.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 11211 =      0.000 ...    87.586 secs
# Ready.
# Reading 0 ... 11211  =      0.000 ...    87.586 secs...
# Not setting metadata
# 9 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 9 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v127.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v129.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v127.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
#     Range : 0 ... 14724 =      0.000 ...   115.031 secs
# Ready.
# Reading 0 ... 14724  =      0.000 ...   115.031 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v125.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15381 =      0.000 ...   120.164 secs
# Ready.
# Reading 0 ... 15381  =      0.000 ...   120.164 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v123.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v125.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v123.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 14553 =      0.000 ...   113.695 secs
# Ready.
# Reading 0 ... 14553  =      0.000 ...   113.695 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v121.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16380 =      0.000 ...   127.969 secs
# Ready.
# Reading 0 ... 16380  =      0.000 ...   127.969 secs...
# Not setting metadata
# 13 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 13 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v121.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v120.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12036 =      0.000 ...    94.031 secs
# Ready.
# Reading 0 ... 12036  =      0.000 ...    94.031 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v120.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v118.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12010 =      0.000 ...    93.828 secs
# Ready.
# Reading 0 ... 12010  =      0.000 ...    93.828 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v118.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v117.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 25662 =      0.000 ...   200.484 secs
# Ready.
# Reading 0 ... 25662  =      0.000 ...   200.484 secs...
# Not setting metadata
# 21 matching events found
# No baseline correction applied
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v117.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 21 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v307.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 22810 =      0.000 ...   178.203 secs
# Ready.
# Reading 0 ... 22810  =      0.000 ...   178.203 secs...
# Not setting metadata
# 19 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 19 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v307.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v306.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 18304 =      0.000 ...   143.000 secs
# Ready.
# Reading 0 ... 18304  =      0.000 ...   143.000 secs...
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 15 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v305.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v306.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v305.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 22276 =      0.000 ...   174.031 secs
# Ready.
# Reading 0 ... 22276  =      0.000 ...   174.031 secs...
# Not setting metadata
# 18 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 18 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v304.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13403 =      0.000 ...   104.711 secs
# Ready.
# Reading 0 ... 13403  =      0.000 ...   104.711 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v304.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v303.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19225 =      0.000 ...   150.195 secs
# Ready.
# Reading 0 ... 19225  =      0.000 ...   150.195 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v303.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v302.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 17844 =      0.000 ...   139.406 secs
# Ready.
# Reading 0 ... 17844  =      0.000 ...   139.406 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v302.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v300.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 25988 =      0.000 ...   203.031 secs
# Ready.
# Reading 0 ... 25988  =      0.000 ...   203.031 secs...
# Not setting metadata
# 21 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 21 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v300.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/Control_fif/v299.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 22263 =      0.000 ...   173.930 secs
# Ready.
# Reading 0 ... 22263  =      0.000 ...   173.930 secs...
# Not setting metadata
# 18 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/Control_fif/v299.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Using data from preloaded Raw for 18 events and 1280 original time points ...
# 0 bad epochs dropped
# ...
# Ready.
# Reading 0 ... 30276  =      0.000 ...   236.531 secs...
# Not setting metadata
# 25 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 25 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v209.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v206.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 20176 =      0.000 ...   157.625 secs
# Ready.
# Reading 0 ... 20176  =      0.000 ...   157.625 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v206.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v204.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 20459 =      0.000 ...   159.836 secs
# Ready.
# Reading 0 ... 20459  =      0.000 ...   159.836 secs...
# Not setting metadata
# 17 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 17 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v200.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v204.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v200.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12742 =      0.000 ...    99.547 secs
# Ready.
# Reading 0 ... 12742  =      0.000 ...    99.547 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v198.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19624 =      0.000 ...   153.312 secs
# Ready.
# Reading 0 ... 19624  =      0.000 ...   153.312 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v196.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v198.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 13398 =      0.000 ...   104.672 secs
# Ready.
# Reading 0 ... 13398  =      0.000 ...   104.672 secs...
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 11 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v190.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v196.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v190.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15468 =      0.000 ...   120.844 secs
# Ready.
# Reading 0 ... 15468  =      0.000 ...   120.844 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v183.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 18594 =      0.000 ...   145.266 secs
# Ready.
# Reading 0 ... 18594  =      0.000 ...   145.266 secs...
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 15 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v181.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v183.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v181.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 10671 =      0.000 ...    83.367 secs
# Ready.
# Reading 0 ... 10671  =      0.000 ...    83.367 secs...
# Not setting metadata
# 8 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 8 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v179.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 12676 =      0.000 ...    99.031 secs
# Ready.
# Reading 0 ... 12676  =      0.000 ...    99.031 secs...
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 10 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v177.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v179.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v177.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 16700 =      0.000 ...   130.469 secs
# Ready.
# Reading 0 ... 16700  =      0.000 ...   130.469 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v286.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 11468 =      0.000 ...    89.594 secs
# Ready.
# Reading 0 ... 11468  =      0.000 ...    89.594 secs...
# Not setting metadata
# 9 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 9 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v284.fif...
# Isotrak not found
#     Read a total of 1 projection items:
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v286.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v284.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 15386 =      0.000 ...   120.203 secs
# Ready.
# Reading 0 ... 15386  =      0.000 ...   120.203 secs...
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 12 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v279.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 20137 =      0.000 ...   157.320 secs
# Ready.
# Reading 0 ... 20137  =      0.000 ...   157.320 secs...
# Not setting metadata
# 16 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 16 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v274.fif...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v279.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v274.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 17326 =      0.000 ...   135.359 secs
# Ready.
# Reading 0 ... 17326  =      0.000 ...   135.359 secs...
# Not setting metadata
# 14 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 14 events and 1280 original time points ...
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v270.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 23684 =      0.000 ...   185.031 secs
# Ready.
# Reading 0 ... 23684  =      0.000 ...   185.031 secs...
# Not setting metadata
# 19 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 19 events and 1280 original time points ...
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v270.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)
# 0 bad epochs dropped
# Opening raw data file /content/drive/MyDrive/eeg_signals/ADHD_fif/v265.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 18392 =      0.000 ...   143.688 secs
# Ready.
# Reading 0 ... 18392  =      0.000 ...   143.688 secs...
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 15 events and 1280 original time points ...
# 0 bad epochs dropped
# <ipython-input-23-89f995403612>:2: RuntimeWarning: This filename (/content/drive/MyDrive/eeg_signals/ADHD_fif/v265.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   datax=mne.io.read_raw_fif(file_path,preload=True)

# %%
#crating target values for each data
NON_ADHD_epochs_labels=[len(i)*[0] for i in NON_ADHD_epochs_array]
ADHD_epochs_labels=[len(i)*[1] for i in ADHD_epochs_array]
print(len(NON_ADHD_epochs_labels),len(ADHD_epochs_labels))
# Out:
# 60 50

# %%
#adding data of both adhd with control in one array
data_list=NON_ADHD_epochs_array+ADHD_epochs_array
#adding the target values of both adhd and control with eachother
label_list=NON_ADHD_epochs_labels+ADHD_epochs_labels
print(len(data_list),len(label_list))
# Out:
# 110 110

# %%
#stacking the values beside eachother
data_array=np.vstack(data_list)
label_array=np.hstack(label_list)
data_array=np.moveaxis(data_array,1,2)

print(data_array.shape,label_array.shape)
# Out:
# (1571, 1280, 19) (1571,)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv1D, BatchNormalization, LeakyReLU, MaxPool1D, GlobalAveragePooling1D, Dense, Dropout, AveragePooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.backend import clear_session
from tensorflow.keras.optimizers import Adam

# %%
#creating cnn model suitable for the data

model = Sequential([
        layers.Conv1D(filters=8, kernel_size=3, strides=1, input_shape=(1280, 19)), # 1
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        layers.MaxPool1D(pool_size=2, strides=2), # 2
        layers.Conv1D(filters=16, kernel_size=3, strides=1), # 3
        layers.LeakyReLU(),
        layers.MaxPool1D(pool_size=2, strides=2), # 4
        layers.Dropout(0.5),
        layers.Conv1D(filters=32, kernel_size=3, strides=1), # 5
        layers.LeakyReLU(),
        layers.AveragePooling1D(pool_size=2, strides=2), # 6
        layers.Dropout(0.5),
        layers.Conv1D(filters=64, kernel_size=3, strides=1), # 7
        layers.LeakyReLU(),
        layers.AveragePooling1D(pool_size=2, strides=2), # 8
        layers.Conv1D(filters=128, kernel_size=3, strides=1), # 9
        layers.LeakyReLU(),
        layers.AveragePooling1D(pool_size=2, strides=2), # 10
        layers.Conv1D(filters=256, kernel_size=3, strides=1), # 11
        layers.LeakyReLU(),
        layers.GlobalAveragePooling1D(), # 12
        layers.Dense(128), # 13
        layers.LeakyReLU(),
        layers.Dense(64), # 14
        layers.LeakyReLU(),
        layers.Dense(1, activation='sigmoid') # 15
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1278, 8)           464
#
#  batch_normalization (Batch  (None, 1278, 8)           32
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 1278, 8)           0
#
#  max_pooling1d (MaxPooling1  (None, 639, 8)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 637, 16)           400
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 637, 16)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 318, 16)           0
#  g1D)
#
#  dropout (Dropout)           (None, 318, 16)           0
#
#  conv1d_2 (Conv1D)           (None, 316, 32)           1568
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 316, 32)           0
#
#  average_pooling1d (Average  (None, 158, 32)           0
#  Pooling1D)
#
#  dropout_1 (Dropout)         (None, 158, 32)           0
#
#  conv1d_3 (Conv1D)           (None, 156, 64)           6208
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 156, 64)           0
#
#  average_pooling1d_1 (Avera  (None, 78, 64)            0
#  gePooling1D)
#
#  conv1d_4 (Conv1D)           (None, 76, 128)           24704
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 76, 128)           0
#
#  average_pooling1d_2 (Avera  (None, 38, 128)           0
#  gePooling1D)
#
#  conv1d_5 (Conv1D)           (None, 36, 256)           98560
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 36, 256)           0
#
#  global_average_pooling1d (  (None, 256)               0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 128)               32896
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 173153 (676.38 KB)
# Trainable params: 173137 (676.32 KB)
# Non-trainable params: 16 (64.00 Byte)
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split dataset into train, validation, and test sets
train_features, test_val_features, train_labels, test_val_labels = train_test_split(data_array, label_array, test_size=0.2, random_state=42)
val_features, test_features, val_labels, test_labels = train_test_split(test_val_features, test_val_labels, test_size=0.5, random_state=42)

# Standardize features
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features.reshape(-1, train_features.shape[-1])).reshape(train_features.shape)
val_features = scaler.transform(val_features.reshape(-1, val_features.shape[-1])).reshape(val_features.shape)
test_features = scaler.transform(test_features.reshape(-1, test_features.shape[-1])).reshape(test_features.shape)

# %%
# Train the model
model.fit(train_features, train_labels, epochs=50, batch_size=100, validation_data=(val_features, val_labels))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 19s 504ms/step - loss: 0.6955 - accuracy: 0.5080 - val_loss: 0.6855 - val_accuracy: 0.5796
# Epoch 2/50
# 13/13 [==============================] - 5s 401ms/step - loss: 0.6752 - accuracy: 0.5836 - val_loss: 0.6764 - val_accuracy: 0.5796
# Epoch 3/50
# 13/13 [==============================] - 5s 387ms/step - loss: 0.6444 - accuracy: 0.6162 - val_loss: 0.6423 - val_accuracy: 0.6051
# Epoch 4/50
# 13/13 [==============================] - 4s 275ms/step - loss: 0.6286 - accuracy: 0.6561 - val_loss: 0.5804 - val_accuracy: 0.7070
# Epoch 5/50
# 13/13 [==============================] - 3s 194ms/step - loss: 0.6042 - accuracy: 0.6656 - val_loss: 0.5863 - val_accuracy: 0.6688
# Epoch 6/50
# 13/13 [==============================] - 3s 239ms/step - loss: 0.5756 - accuracy: 0.7054 - val_loss: 0.6997 - val_accuracy: 0.6242
# Epoch 7/50
# 13/13 [==============================] - 4s 316ms/step - loss: 0.5814 - accuracy: 0.6951 - val_loss: 0.6122 - val_accuracy: 0.6497
# Epoch 8/50
# 13/13 [==============================] - 3s 199ms/step - loss: 0.5938 - accuracy: 0.6871 - val_loss: 0.5784 - val_accuracy: 0.6943
# Epoch 9/50
# 13/13 [==============================] - 3s 194ms/step - loss: 0.5396 - accuracy: 0.7277 - val_loss: 0.5374 - val_accuracy: 0.7325
# Epoch 10/50
# 13/13 [==============================] - 3s 194ms/step - loss: 0.5824 - accuracy: 0.6982 - val_loss: 0.5453 - val_accuracy: 0.7707
# Epoch 11/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.5514 - accuracy: 0.7269 - val_loss: 0.5742 - val_accuracy: 0.6879
# Epoch 12/50
# 13/13 [==============================] - 4s 337ms/step - loss: 0.5321 - accuracy: 0.7301 - val_loss: 0.5563 - val_accuracy: 0.6943
# Epoch 13/50
# 13/13 [==============================] - 3s 196ms/step - loss: 0.5200 - accuracy: 0.7468 - val_loss: 0.5442 - val_accuracy: 0.7134
# Epoch 14/50
# 13/13 [==============================] - 3s 197ms/step - loss: 0.5420 - accuracy: 0.7062 - val_loss: 0.6338 - val_accuracy: 0.6115
# Epoch 15/50
# 13/13 [==============================] - 3s 199ms/step - loss: 0.5263 - accuracy: 0.7396 - val_loss: 0.5788 - val_accuracy: 0.6624
# Epoch 16/50
# 13/13 [==============================] - 3s 201ms/step - loss: 0.4972 - accuracy: 0.7484 - val_loss: 0.4727 - val_accuracy: 0.8025
# Epoch 17/50
# 13/13 [==============================] - 4s 337ms/step - loss: 0.4917 - accuracy: 0.7604 - val_loss: 0.5320 - val_accuracy: 0.7389
# Epoch 18/50
# 13/13 [==============================] - 3s 204ms/step - loss: 0.4936 - accuracy: 0.7588 - val_loss: 0.4825 - val_accuracy: 0.7898
# Epoch 19/50
# 13/13 [==============================] - 4s 282ms/step - loss: 0.4805 - accuracy: 0.7667 - val_loss: 0.4985 - val_accuracy: 0.7389
# Epoch 20/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.5109 - accuracy: 0.7540 - val_loss: 0.5223 - val_accuracy: 0.7134
# Epoch 21/50
# 13/13 [==============================] - 4s 276ms/step - loss: 0.4959 - accuracy: 0.7436 - val_loss: 0.4435 - val_accuracy: 0.8217
# Epoch 22/50
# 13/13 [==============================] - 4s 287ms/step - loss: 0.4646 - accuracy: 0.7755 - val_loss: 0.4320 - val_accuracy: 0.8217
# Epoch 23/50
# 13/13 [==============================] - 3s 193ms/step - loss: 0.4557 - accuracy: 0.7834 - val_loss: 0.4237 - val_accuracy: 0.8153
# Epoch 24/50
# 13/13 [==============================] - 2s 191ms/step - loss: 0.4580 - accuracy: 0.7850 - val_loss: 0.4642 - val_accuracy: 0.7898
# Epoch 25/50
# 13/13 [==============================] - 3s 193ms/step - loss: 0.4488 - accuracy: 0.7811 - val_loss: 0.4508 - val_accuracy: 0.7962
# Epoch 26/50
# 13/13 [==============================] - 4s 333ms/step - loss: 0.4286 - accuracy: 0.7954 - val_loss: 0.4397 - val_accuracy: 0.7962
# Epoch 27/50
# 13/13 [==============================] - 4s 290ms/step - loss: 0.4408 - accuracy: 0.7922 - val_loss: 0.5266 - val_accuracy: 0.7580
# Epoch 28/50
# 13/13 [==============================] - 3s 196ms/step - loss: 0.4680 - accuracy: 0.7803 - val_loss: 0.4173 - val_accuracy: 0.8344
# Epoch 29/50
# 13/13 [==============================] - 3s 197ms/step - loss: 0.4138 - accuracy: 0.8177 - val_loss: 0.4059 - val_accuracy: 0.8344
# Epoch 30/50
# 13/13 [==============================] - 3s 256ms/step - loss: 0.4311 - accuracy: 0.7890 - val_loss: 0.4604 - val_accuracy: 0.7962
# Epoch 31/50
# 13/13 [==============================] - 4s 288ms/step - loss: 0.4244 - accuracy: 0.8041 - val_loss: 0.4190 - val_accuracy: 0.8344
# Epoch 32/50
# 13/13 [==============================] - 4s 289ms/step - loss: 0.4261 - accuracy: 0.7970 - val_loss: 0.3656 - val_accuracy: 0.8471
# Epoch 33/50
# 13/13 [==============================] - 3s 201ms/step - loss: 0.4337 - accuracy: 0.7930 - val_loss: 0.3760 - val_accuracy: 0.8344
# Epoch 34/50
# 13/13 [==============================] - 3s 198ms/step - loss: 0.4003 - accuracy: 0.8073 - val_loss: 0.4003 - val_accuracy: 0.8344
# Epoch 35/50
# 13/13 [==============================] - 3s 198ms/step - loss: 0.4159 - accuracy: 0.7930 - val_loss: 0.3788 - val_accuracy: 0.8471
# Epoch 36/50
# 13/13 [==============================] - 3s 269ms/step - loss: 0.3963 - accuracy: 0.8161 - val_loss: 0.3529 - val_accuracy: 0.8408
# Epoch 37/50
# 13/13 [==============================] - 4s 292ms/step - loss: 0.3944 - accuracy: 0.8129 - val_loss: 0.3719 - val_accuracy: 0.8408
# Epoch 38/50
# 13/13 [==============================] - 3s 244ms/step - loss: 0.4068 - accuracy: 0.8049 - val_loss: 0.3743 - val_accuracy: 0.8344
# Epoch 39/50
# 13/13 [==============================] - 3s 250ms/step - loss: 0.3710 - accuracy: 0.8320 - val_loss: 0.3514 - val_accuracy: 0.8408
# Epoch 40/50
# 13/13 [==============================] - 3s 203ms/step - loss: 0.4368 - accuracy: 0.7914 - val_loss: 0.3324 - val_accuracy: 0.8471
# Epoch 41/50
# 13/13 [==============================] - 4s 320ms/step - loss: 0.4061 - accuracy: 0.8065 - val_loss: 0.3804 - val_accuracy: 0.8408
# Epoch 42/50
# 13/13 [==============================] - 3s 243ms/step - loss: 0.4033 - accuracy: 0.8153 - val_loss: 0.3630 - val_accuracy: 0.8344
# Epoch 43/50
# 13/13 [==============================] - 3s 207ms/step - loss: 0.3813 - accuracy: 0.8232 - val_loss: 0.3321 - val_accuracy: 0.8471
# Epoch 44/50
# 13/13 [==============================] - 3s 198ms/step - loss: 0.3770 - accuracy: 0.8145 - val_loss: 0.3939 - val_accuracy: 0.8344
# Epoch 45/50
# 13/13 [==============================] - 3s 195ms/step - loss: 0.3585 - accuracy: 0.8304 - val_loss: 0.3239 - val_accuracy: 0.8662
# Epoch 46/50
# 13/13 [==============================] - 4s 327ms/step - loss: 0.3575 - accuracy: 0.8256 - val_loss: 0.3890 - val_accuracy: 0.8280
# Epoch 47/50
# 13/13 [==============================] - 3s 237ms/step - loss: 0.3412 - accuracy: 0.8432 - val_loss: 0.3184 - val_accuracy: 0.8408
# Epoch 48/50
# 13/13 [==============================] - 3s 194ms/step - loss: 0.3683 - accuracy: 0.8280 - val_loss: 0.3789 - val_accuracy: 0.8280
# Epoch 49/50
# 13/13 [==============================] - 3s 195ms/step - loss: 0.3600 - accuracy: 0.8320 - val_loss: 0.3516 - val_accuracy: 0.8535
# Epoch 50/50
# 13/13 [==============================] - 3s 198ms/step - loss: 0.3327 - accuracy: 0.8439 - val_loss: 0.3444 - val_accuracy: 0.8535

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
# Make predictions on test set
predictions = model.predict(test_features)
binary_predictions = np.round(predictions).flatten()

# Calculate confusion matrix
cm = confusion_matrix(test_labels, binary_predictions)

# Plot confusion matrix
labels = ['Normal', 'adhd']
display_labels = ['True ' + label for label in labels]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.show()

accuracy=[]
# Calculate accuracy
accuracy.append(model.evaluate(test_features, test_labels)[1])
# Out:
# 5/5 [==============================] - 1s 33ms/step
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4610 - accuracy: 0.8165

# %%
#calculating sensitivity and specificity
tn, fp, fn, tp = cm.ravel()

sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
print(f"Sensitivity: {sensitivity}")
print(f"Specificity: {specificity}")
# Out:
# Sensitivity: 1.0
# Specificity: 0.6282051282051282

# %%
from sklearn.metrics import classification_report

# Calculate precision, recall, F1-score, and support
report = classification_report(test_labels, binary_predictions, target_names=['NORMAL', 'ADHD'])

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       1.00      0.63      0.77        78
#         ADHD       0.73      1.00      0.85        80
#
#     accuracy                           0.82       158
#    macro avg       0.87      0.81      0.81       158
# weighted avg       0.87      0.82      0.81       158

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve and ROC area for each class
fpr, tpr, _ = roc_curve(test_labels, binary_predictions)

# Calculate area under the curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
